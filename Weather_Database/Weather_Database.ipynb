# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations. and zip the 2 lists together into a tuple
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a271ae8279f616bdbded0f5d3d2a724a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | thinadhoo
# Processing Record 9 of Set 1 | barranca
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | ostersund
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | kurakh
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | makaha
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | broome
# Processing Record 21 of Set 1 | trat
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | tecoanapa
# Processing Record 24 of Set 1 | pemangkat
# Processing Record 25 of Set 1 | tabou
# Processing Record 26 of Set 1 | rairangpur
# Processing Record 27 of Set 1 | pacific grove
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | kajaani
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | ribeirao bonito
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | quarai
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | kalmunai
# Processing Record 38 of Set 1 | soyo
# Processing Record 39 of Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | la palma
# Processing Record 42 of Set 1 | vanimo
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | faya
# Processing Record 46 of Set 1 | terra santa
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | alofi
# Processing Record 50 of Set 1 | moussoro
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 2 | tongliao
# Processing Record 4 of Set 2 | altay
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 2 | los llanos de aridane
# Processing Record 9 of Set 2 | ahipara
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | ishigaki
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | itarema
# Processing Record 15 of Set 2 | bagotville
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | antropovo
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | nizhnevartovsk
# Processing Record 20 of Set 2 | decatur
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | tazmalt
# Processing Record 23 of Set 2 | jiuquan
# Processing Record 24 of Set 2 | diu
# Processing Record 25 of Set 2 | taoudenni
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | iracoubo
# Processing Record 31 of Set 2 | dingle
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | nyurba
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | nandyal
# Processing Record 37 of Set 2 | oranjestad
# Processing Record 38 of Set 2 | angoche
# Processing Record 39 of Set 2 | winneba
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | voyvozh
# Processing Record 46 of Set 2 | am timan
# Processing Record 47 of Set 2 | tessalit
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | burnie
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 3 | nome
# Processing Record 3 of Set 3 | sorland
# Processing Record 4 of Set 3 | cape town
# Processing Record 5 of Set 3 | zlatibor
# Processing Record 6 of Set 3 | xicotencatl
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | aranos
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | eureka
# Processing Record 12 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 3 | oistins
# Processing Record 14 of Set 3 | saint-augustin
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | caldwell
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | klaksvik
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | laguna
# Processing Record 21 of Set 3 | jacqueville
# Processing Record 22 of Set 3 | mogadishu
# Processing Record 23 of Set 3 | shache
# Processing Record 24 of Set 3 | kirakira
# Processing Record 25 of Set 3 | bakel
# Processing Record 26 of Set 3 | izacic
# Processing Record 27 of Set 3 | porto velho
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | pedernales
# Processing Record 30 of Set 3 | poronaysk
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | dondo
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | odesskoye
# Processing Record 35 of Set 3 | trairi
# Processing Record 36 of Set 3 | araouane
# Processing Record 37 of Set 3 | kavaratti
# Processing Record 38 of Set 3 | aklavik
# Processing Record 39 of Set 3 | sur
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | dunedin
# Processing Record 43 of Set 3 | santiago
# Processing Record 44 of Set 3 | vostok
# Processing Record 45 of Set 3 | bumba
# Processing Record 46 of Set 3 | san cristobal
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | komsomolskiy
# Processing Record 49 of Set 3 | college
# Processing Record 50 of Set 3 | nanortalik
# Processing Record 1 of Set 4 | ulladulla
# Processing Record 2 of Set 4 | almeria
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | flinders
# Processing Record 5 of Set 4 | hariana
# Processing Record 6 of Set 4 | capim grosso
# Processing Record 7 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 8 of Set 4 | cukai
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | havoysund
# Processing Record 11 of Set 4 | springfield
# Processing Record 12 of Set 4 | sawtell
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | pangody
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | santa ines
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | erenhot
# Processing Record 19 of Set 4 | launceston
# Processing Record 20 of Set 4 | tautira
# Processing Record 21 of Set 4 | helena
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | olavarria
# Processing Record 24 of Set 4 | bam
# Processing Record 25 of Set 4 | teya
# Processing Record 26 of Set 4 | cambui
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | itamaraca
# Processing Record 30 of Set 4 | sihora
# Processing Record 31 of Set 4 | amboasary
# Processing Record 32 of Set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | honningsvag
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | mariental
# Processing Record 37 of Set 4 | namibe
# Processing Record 38 of Set 4 | omsukchan
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | raudeberg
# Processing Record 42 of Set 4 | sasebo
# Processing Record 43 of Set 4 | ledyard
# Processing Record 44 of Set 4 | baraki barak
# Processing Record 45 of Set 4 | ola
# Processing Record 46 of Set 4 | opuwo
# Processing Record 47 of Set 4 | bathsheba
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | grand gaube
# Processing Record 50 of Set 4 | martapura
# Processing Record 1 of Set 5 | mackay
# Processing Record 2 of Set 5 | port keats
# Processing Record 3 of Set 5 | chapais
# Processing Record 4 of Set 5 | linkoping
# Processing Record 5 of Set 5 | mayumba
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | jambi
# Processing Record 9 of Set 5 | pemba
# Processing Record 10 of Set 5 | yatou
# Processing Record 11 of Set 5 | kati
# Processing Record 12 of Set 5 | belyy yar
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | bokoro
# Processing Record 15 of Set 5 | fandriana
# Processing Record 16 of Set 5 | nakusp
# Processing Record 17 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 5 | port moresby
# Processing Record 19 of Set 5 | sao jose da coroa grande
# Processing Record 20 of Set 5 | abeche
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 5 | half moon bay
# Processing Record 23 of Set 5 | saskylakh
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | lazaro cardenas
# Processing Record 27 of Set 5 | paranagua
# Processing Record 28 of Set 5 | tayu
# Processing Record 29 of Set 5 | middelburg
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | gimbi
# Processing Record 32 of Set 5 | kilindoni
# Processing Record 33 of Set 5 | asau
# Processing Record 34 of Set 5 | kupang
# Processing Record 35 of Set 5 | rio gallegos
# Processing Record 36 of Set 5 | bahia honda
# Processing Record 37 of Set 5 | westport
# Processing Record 38 of Set 5 | riyadh
# Processing Record 39 of Set 5 | nantucket
# Processing Record 40 of Set 5 | vagay
# Processing Record 41 of Set 5 | jalu
# Processing Record 42 of Set 5 | ritchie
# Processing Record 43 of Set 5 | dieppe
# Processing Record 44 of Set 5 | atikokan
# Processing Record 45 of Set 5 | srandakan
# Processing Record 46 of Set 5 | frejus
# Processing Record 47 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 5 | maniitsoq
# Processing Record 49 of Set 5 | ust-kuyga
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | tateyama
# Processing Record 2 of Set 6 | kushima
# Processing Record 3 of Set 6 | torata
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | seydi
# Processing Record 6 of Set 6 | harlingen
# Processing Record 7 of Set 6 | monsenhor gil
# Processing Record 8 of Set 6 | muros
# Processing Record 9 of Set 6 | kabalo
# Processing Record 10 of Set 6 | ouricuri
# Processing Record 11 of Set 6 | greensburg
# Processing Record 12 of Set 6 | jacareacanga
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | northfield
# Processing Record 16 of Set 6 | richards bay
# Processing Record 17 of Set 6 | los zacatones
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | tlapehuala
# Processing Record 20 of Set 6 | matamoros
# Processing Record 21 of Set 6 | obo
# Processing Record 22 of Set 6 | kulaman
# Processing Record 23 of Set 6 | pierre
# Processing Record 24 of Set 6 | storslett
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | lebedinyy
# Processing Record 28 of Set 6 | payo
# Processing Record 29 of Set 6 | hovd
# Processing Record 30 of Set 6 | arrecife
# Processing Record 31 of Set 6 | henties bay
# Processing Record 32 of Set 6 | axim
# Processing Record 33 of Set 6 | todos santos
# Processing Record 34 of Set 6 | ponta do sol
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | beian
# Processing Record 37 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 6 | sumbe
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | buluang
# Processing Record 42 of Set 6 | liuzhou
# Processing Record 43 of Set 6 | esperance
# Processing Record 44 of Set 6 | pokhara
# Processing Record 45 of Set 6 | uray
# Processing Record 46 of Set 6 | mantua
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | samarai
# Processing Record 49 of Set 6 | kondinskoye
# Processing Record 50 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 7 | tarakan
# Processing Record 2 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 7 | camacha
# Processing Record 4 of Set 7 | rocha
# Processing Record 5 of Set 7 | galle
# Processing Record 6 of Set 7 | port lincoln
# Processing Record 7 of Set 7 | karpathos
# Processing Record 8 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 7 | east london
# Processing Record 10 of Set 7 | bairiki
# Processing Record 11 of Set 7 | itaituba
# Processing Record 12 of Set 7 | mariinsk
# Processing Record 13 of Set 7 | vila
# Processing Record 14 of Set 7 | nchelenge
# Processing Record 15 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 7 | kruisfontein
# Processing Record 17 of Set 7 | obidos
# Processing Record 18 of Set 7 | nichinan
# Processing Record 19 of Set 7 | eyrarbakki
# Processing Record 20 of Set 7 | huarmey
# Processing Record 21 of Set 7 | souillac
# Processing Record 22 of Set 7 | mbour
# Processing Record 23 of Set 7 | mulege
# Processing Record 24 of Set 7 | serebryanyy bor
# Processing Record 25 of Set 7 | moose factory
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | khani
# Processing Record 28 of Set 7 | verkhnyaya toyma
# Processing Record 29 of Set 7 | mwene-ditu
# Processing Record 30 of Set 7 | san patricio
# Processing Record 31 of Set 7 | pochutla
# Processing Record 32 of Set 7 | tunceli
# Processing Record 33 of Set 7 | butaritari
# Processing Record 34 of Set 7 | atambua
# Processing Record 35 of Set 7 | uyuni
# Processing Record 36 of Set 7 | vardo
# Processing Record 37 of Set 7 | holstebro
# Processing Record 38 of Set 7 | batemans bay
# Processing Record 39 of Set 7 | dzhebariki-khaya
# Processing Record 40 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 7 | zhanaozen
# Processing Record 42 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 7 | bubaque
# Processing Record 44 of Set 7 | sri aman
# Processing Record 45 of Set 7 | belaya gora
# Processing Record 46 of Set 7 | mansa
# Processing Record 47 of Set 7 | oussouye
# Processing Record 48 of Set 7 | homer
# Processing Record 49 of Set 7 | vrable
# Processing Record 50 of Set 7 | janakpur
# Processing Record 1 of Set 8 | matay
# Processing Record 2 of Set 8 | starobaltachevo
# Processing Record 3 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 8 | mayo
# Processing Record 5 of Set 8 | pangnirtung
# Processing Record 6 of Set 8 | the pas
# Processing Record 7 of Set 8 | yulara
# Processing Record 8 of Set 8 | limbang
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | xuddur
# Processing Record 11 of Set 8 | bergerac
# Processing Record 12 of Set 8 | kopyevo
# City not found. Skipping...
# Processing Record 13 of Set 8 | zhaotong
# Processing Record 14 of Set 8 | sisimiut
# Processing Record 15 of Set 8 | shiyan
# Processing Record 16 of Set 8 | deputatskiy
# Processing Record 17 of Set 8 | varkaus
# Processing Record 18 of Set 8 | yuxia
# Processing Record 19 of Set 8 | nouakchott
# Processing Record 20 of Set 8 | cockburn town
# Processing Record 21 of Set 8 | algiers
# Processing Record 22 of Set 8 | ixtapa
# Processing Record 23 of Set 8 | labuhan
# Processing Record 24 of Set 8 | tiarei
# Processing Record 25 of Set 8 | grindavik
# Processing Record 26 of Set 8 | nurota
# Processing Record 27 of Set 8 | el tigre
# Processing Record 28 of Set 8 | tikrit
# Processing Record 29 of Set 8 | zabol
# Processing Record 30 of Set 8 | carmarthen
# Processing Record 31 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 8 | saldanha
# Processing Record 33 of Set 8 | imatra
# Processing Record 34 of Set 8 | palotina
# Processing Record 35 of Set 8 | bitkine
# Processing Record 36 of Set 8 | morococha
# Processing Record 37 of Set 8 | kawalu
# Processing Record 38 of Set 8 | nemuro
# Processing Record 39 of Set 8 | la cumbre
# Processing Record 40 of Set 8 | alta floresta
# Processing Record 41 of Set 8 | cururupu
# Processing Record 42 of Set 8 | herat
# Processing Record 43 of Set 8 | nizwa
# Processing Record 44 of Set 8 | kaihua
# Processing Record 45 of Set 8 | guerrero negro
# Processing Record 46 of Set 8 | rodrigues alves
# Processing Record 47 of Set 8 | cap-aux-meules
# Processing Record 48 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 8 | kiruna
# Processing Record 50 of Set 8 | pokrovsk
# Processing Record 1 of Set 9 | biloela
# Processing Record 2 of Set 9 | korsakov
# Processing Record 3 of Set 9 | olafsvik
# Processing Record 4 of Set 9 | merauke
# Processing Record 5 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 9 | kutum
# Processing Record 7 of Set 9 | yichang
# Processing Record 8 of Set 9 | acarau
# Processing Record 9 of Set 9 | morrope
# Processing Record 10 of Set 9 | shikarpur
# Processing Record 11 of Set 9 | miskolc
# Processing Record 12 of Set 9 | bonavista
# Processing Record 13 of Set 9 | karratha
# Processing Record 14 of Set 9 | belmonte
# Processing Record 15 of Set 9 | rancho palos verdes
# Processing Record 16 of Set 9 | penzance
# Processing Record 17 of Set 9 | houma
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | alcantara
# Processing Record 20 of Set 9 | vestmannaeyjar
# Processing Record 21 of Set 9 | chama
# Processing Record 22 of Set 9 | pokaran
# Processing Record 23 of Set 9 | lykhivka
# Processing Record 24 of Set 9 | alindao
# Processing Record 25 of Set 9 | quelimane
# Processing Record 26 of Set 9 | xirokambos
# City not found. Skipping...
# Processing Record 27 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 9 | mancio lima
# Processing Record 29 of Set 9 | pimentel
# Processing Record 30 of Set 9 | kahului
# Processing Record 31 of Set 9 | taywarah
# Processing Record 32 of Set 9 | rio grande
# Processing Record 33 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | cabedelo
# Processing Record 36 of Set 9 | gemena
# Processing Record 37 of Set 9 | fernley
# Processing Record 38 of Set 9 | new plymouth
# Processing Record 39 of Set 9 | bandarbeyla
# Processing Record 40 of Set 9 | buraydah
# Processing Record 41 of Set 9 | inhambane
# Processing Record 42 of Set 9 | bajmok
# Processing Record 43 of Set 9 | morant bay
# Processing Record 44 of Set 9 | coquimbo
# Processing Record 45 of Set 9 | irara
# Processing Record 46 of Set 9 | tera
# Processing Record 47 of Set 9 | vao
# Processing Record 48 of Set 9 | benguela
# Processing Record 49 of Set 9 | faranah
# Processing Record 50 of Set 9 | padang
# Processing Record 1 of Set 10 | yeppoon
# Processing Record 2 of Set 10 | ojinaga
# Processing Record 3 of Set 10 | strezhevoy
# Processing Record 4 of Set 10 | duz
# City not found. Skipping...
# Processing Record 5 of Set 10 | eydhafushi
# Processing Record 6 of Set 10 | nouadhibou
# Processing Record 7 of Set 10 | chino valley
# Processing Record 8 of Set 10 | dublin
# Processing Record 9 of Set 10 | illora
# Processing Record 10 of Set 10 | havelock
# Processing Record 11 of Set 10 | airai
# Processing Record 12 of Set 10 | mandalgovi
# Processing Record 13 of Set 10 | sukhovolya
# Processing Record 14 of Set 10 | bosaso
# Processing Record 15 of Set 10 | yagodnoye
# Processing Record 16 of Set 10 | waitati
# Processing Record 17 of Set 10 | dar es salaam
# Processing Record 18 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 19 of Set 10 | tuktoyaktuk
# Processing Record 20 of Set 10 | chicama
# Processing Record 21 of Set 10 | pindiga
# Processing Record 22 of Set 10 | yelizovo
# Processing Record 23 of Set 10 | taga dzong
# City not found. Skipping...
# Processing Record 24 of Set 10 | gizo
# Processing Record 25 of Set 10 | vila velha
# Processing Record 26 of Set 10 | sangmelima
# Processing Record 27 of Set 10 | dunda
# Processing Record 28 of Set 10 | tambacounda
# Processing Record 29 of Set 10 | miracema do tocantins
# Processing Record 30 of Set 10 | harnosand
# Processing Record 31 of Set 10 | maningrida
# Processing Record 32 of Set 10 | camocim
# Processing Record 33 of Set 10 | wicklow
# Processing Record 34 of Set 10 | denpasar
# Processing Record 35 of Set 10 | afrikanda
# Processing Record 36 of Set 10 | miranda
# Processing Record 37 of Set 10 | at-bashi
# Processing Record 38 of Set 10 | ancud
# Processing Record 39 of Set 10 | vila franca do campo
# Processing Record 40 of Set 10 | salym
# Processing Record 41 of Set 10 | te anau
# Processing Record 42 of Set 10 | waldshut-tiengen
# Processing Record 43 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 10 | chapayeve
# Processing Record 45 of Set 10 | shumerlya
# Processing Record 46 of Set 10 | usolye
# Processing Record 47 of Set 10 | tartagal
# Processing Record 48 of Set 10 | cap malheureux
# Processing Record 49 of Set 10 | karabash
# Processing Record 50 of Set 10 | caravelas
# Processing Record 1 of Set 11 | talnakh
# Processing Record 2 of Set 11 | baghdad
# Processing Record 3 of Set 11 | booue
# Processing Record 4 of Set 11 | zverinogolovskoye
# Processing Record 5 of Set 11 | longjiang
# Processing Record 6 of Set 11 | beloha
# Processing Record 7 of Set 11 | hamilton
# Processing Record 8 of Set 11 | san andres
# Processing Record 9 of Set 11 | vung tau
# Processing Record 10 of Set 11 | llanes
# Processing Record 11 of Set 11 | baft
# Processing Record 12 of Set 11 | oranjemund
# Processing Record 13 of Set 11 | staritsa
# Processing Record 14 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 11 | eirunepe
# Processing Record 16 of Set 11 | ulagan
# Processing Record 17 of Set 11 | lasa
# Processing Record 18 of Set 11 | flin flon
# Processing Record 19 of Set 11 | shelburne
# Processing Record 20 of Set 11 | mamallapuram
# Processing Record 21 of Set 11 | tual
# Processing Record 22 of Set 11 | hit
# Processing Record 23 of Set 11 | yuci
# Processing Record 24 of Set 11 | casas grandes
# Processing Record 25 of Set 11 | lubao
# Processing Record 26 of Set 11 | borazjan
# Processing Record 27 of Set 11 | stokmarknes
# Processing Record 28 of Set 11 | nicholasville
# Processing Record 29 of Set 11 | jijiga
# Processing Record 30 of Set 11 | sibolga
# Processing Record 31 of Set 11 | sechura
# Processing Record 32 of Set 11 | puerto narino
# Processing Record 33 of Set 11 | maldonado
# Processing Record 34 of Set 11 | asfi
# Processing Record 35 of Set 11 | walvis bay
# Processing Record 36 of Set 11 | aitape
# Processing Record 37 of Set 11 | yumen
# Processing Record 38 of Set 11 | srivardhan
# Processing Record 39 of Set 11 | gaya
# Processing Record 40 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 11 | daoukro
# Processing Record 42 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 11 | xining
# Processing Record 44 of Set 11 | emerald
# Processing Record 45 of Set 11 | cedar city
# Processing Record 46 of Set 11 | borovichi
# Processing Record 47 of Set 11 | olean
# Processing Record 48 of Set 11 | fevik
# Processing Record 49 of Set 11 | sept-iles
# Processing Record 50 of Set 11 | tulun
# Processing Record 1 of Set 12 | semnan
# Processing Record 2 of Set 12 | gorontalo
# Processing Record 3 of Set 12 | srednekolymsk
# Processing Record 4 of Set 12 | tevaitoa
# Processing Record 5 of Set 12 | dicabisagan
# Processing Record 6 of Set 12 | ondjiva
# Processing Record 7 of Set 12 | sinnamary
# Processing Record 8 of Set 12 | koilas
# Processing Record 9 of Set 12 | colombo
# Processing Record 10 of Set 12 | mount hagen
# Processing Record 11 of Set 12 | saint-joseph
# Processing Record 12 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 13 of Set 12 | tura
# Processing Record 14 of Set 12 | pyu
# Processing Record 15 of Set 12 | beringovskiy
# Processing Record 16 of Set 12 | shingu
# Processing Record 17 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 18 of Set 12 | hambantota
# Processing Record 19 of Set 12 | porto murtinho
# Processing Record 20 of Set 12 | winslow
# Processing Record 21 of Set 12 | limoeiro do ajuru
# Processing Record 22 of Set 12 | port pirie
# Processing Record 23 of Set 12 | christchurch
# Processing Record 24 of Set 12 | ambilobe
# Processing Record 25 of Set 12 | mashhad
# Processing Record 26 of Set 12 | novobelokatay
# Processing Record 27 of Set 12 | tingi
# Processing Record 28 of Set 12 | namatanai
# Processing Record 29 of Set 12 | yining
# Processing Record 30 of Set 12 | banjar
# Processing Record 31 of Set 12 | bemidji
# Processing Record 32 of Set 12 | haimen
# Processing Record 33 of Set 12 | isla mujeres
# Processing Record 34 of Set 12 | mount gambier
# Processing Record 35 of Set 12 | hlotse
# Processing Record 36 of Set 12 | lure
# Processing Record 37 of Set 12 | lima
# Processing Record 38 of Set 12 | ontario
# Processing Record 39 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 40 of Set 12 | clyde river
# Processing Record 41 of Set 12 | saint-francois
# Processing Record 42 of Set 12 | taggia
# Processing Record 43 of Set 12 | umm lajj
# Processing Record 44 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 12 | pringsewu
# Processing Record 48 of Set 12 | nabire
# Processing Record 49 of Set 12 | panalingaan
# Processing Record 50 of Set 12 | gat
# Processing Record 1 of Set 13 | ostrovnoy
# Processing Record 2 of Set 13 | bira
# Processing Record 3 of Set 13 | kincardine
# Processing Record 4 of Set 13 | zhigansk
# Processing Record 5 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 6 of Set 13 | casper
# Processing Record 7 of Set 13 | seryshevo
# Processing Record 8 of Set 13 | guspini
# Processing Record 9 of Set 13 | margate
# Processing Record 10 of Set 13 | novikovo
# Processing Record 11 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 12 of Set 13 | birao
# Processing Record 13 of Set 13 | xinzhou
# Processing Record 14 of Set 13 | sungaipenuh
# Processing Record 15 of Set 13 | itoman
# Processing Record 16 of Set 13 | mwinilunga
# Processing Record 17 of Set 13 | rehoboth
# Processing Record 18 of Set 13 | daru
# Processing Record 19 of Set 13 | road town
# Processing Record 20 of Set 13 | constitucion
# Processing Record 21 of Set 13 | harper
# Processing Record 22 of Set 13 | talaya
# Processing Record 23 of Set 13 | praya
# Processing Record 24 of Set 13 | batagay
# Processing Record 25 of Set 13 | matara
# Processing Record 26 of Set 13 | chuy
# Processing Record 27 of Set 13 | paamiut
# Processing Record 28 of Set 13 | novopavlovka
# Processing Record 29 of Set 13 | doha
# Processing Record 30 of Set 13 | abaza
# Processing Record 31 of Set 13 | havre-saint-pierre
# Processing Record 32 of Set 13 | labrea
# Processing Record 33 of Set 13 | lipin bor
# Processing Record 34 of Set 13 | naron
# Processing Record 35 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 13 | aras
# Processing Record 37 of Set 13 | sigerfjord
# City not found. Skipping...
# Processing Record 38 of Set 13 | hadrut
# Processing Record 39 of Set 13 | pangai
# Processing Record 40 of Set 13 | arifwala
# Processing Record 41 of Set 13 | noumea
# Processing Record 42 of Set 13 | kokopo
# Processing Record 43 of Set 13 | leshukonskoye
# Processing Record 44 of Set 13 | port hedland
# Processing Record 45 of Set 13 | svetlogorsk
# Processing Record 46 of Set 13 | lewiston
# Processing Record 47 of Set 13 | parrita
# Processing Record 48 of Set 13 | enshi
# Processing Record 49 of Set 13 | portland
# Processing Record 50 of Set 13 | ayan
# Processing Record 1 of Set 14 | gornozavodsk
# Processing Record 2 of Set 14 | hirara
# Processing Record 3 of Set 14 | waddan
# Processing Record 4 of Set 14 | arlit
# Processing Record 5 of Set 14 | mindelo
# Processing Record 6 of Set 14 | tilichiki
# Processing Record 7 of Set 14 | puerto escondido
# Processing Record 8 of Set 14 | fushan
# Processing Record 9 of Set 14 | verkhnyaya inta
# Processing Record 10 of Set 14 | bongor
# Processing Record 11 of Set 14 | calvinia
# Processing Record 12 of Set 14 | klichka
# Processing Record 13 of Set 14 | hearst
# Processing Record 14 of Set 14 | iluppur
# Processing Record 15 of Set 14 | roebourne
# Processing Record 16 of Set 14 | linfen
# Processing Record 17 of Set 14 | santa maria
# Processing Record 18 of Set 14 | tornio
# Processing Record 19 of Set 14 | ossora
# Processing Record 20 of Set 14 | san jose
# Processing Record 21 of Set 14 | dudinka
# Processing Record 22 of Set 14 | fort nelson
# Processing Record 23 of Set 14 | turukhansk
# Processing Record 24 of Set 14 | sudzha
# Processing Record 25 of Set 14 | xichang
# Processing Record 26 of Set 14 | port blair
# Processing Record 27 of Set 14 | suntar
# Processing Record 28 of Set 14 | fallon
# Processing Record 29 of Set 14 | kankon
# Processing Record 30 of Set 14 | jiaocheng
# Processing Record 31 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 32 of Set 14 | banda aceh
# Processing Record 33 of Set 14 | palmer
# Processing Record 34 of Set 14 | narsaq
# Processing Record 35 of Set 14 | rawson
# Processing Record 36 of Set 14 | berezovyy
# Processing Record 37 of Set 14 | skagen
# Processing Record 38 of Set 14 | najran
# Processing Record 39 of Set 14 | palu
# Processing Record 40 of Set 14 | yara
# Processing Record 41 of Set 14 | bolivar
# Processing Record 42 of Set 14 | omboue
# Processing Record 43 of Set 14 | bogorodskoye
# Processing Record 44 of Set 14 | berlevag
# Processing Record 45 of Set 14 | buala
# Processing Record 46 of Set 14 | bulri
# Processing Record 47 of Set 14 | ust-tsilma
# Processing Record 48 of Set 14 | kunya
# Processing Record 49 of Set 14 | amazar
# Processing Record 50 of Set 14 | arona
# Processing Record 1 of Set 15 | kailua
# Processing Record 2 of Set 15 | moron
# Processing Record 3 of Set 15 | rialma
# Processing Record 4 of Set 15 | tarauaca
# Processing Record 5 of Set 15 | stromness
# Processing Record 6 of Set 15 | pittsburg
# Processing Record 7 of Set 15 | bud
# Processing Record 8 of Set 15 | litovko
# Processing Record 9 of Set 15 | copenhagen
# Processing Record 10 of Set 15 | malartic
# Processing Record 11 of Set 15 | australind
# Processing Record 12 of Set 15 | soria
# Processing Record 13 of Set 15 | vangaindrano
# Processing Record 14 of Set 15 | sorgun
# Processing Record 15 of Set 15 | batavia
# Processing Record 16 of Set 15 | ponta delgada
# Processing Record 17 of Set 15 | mangochi
# Processing Record 18 of Set 15 | mtambile
# Processing Record 19 of Set 15 | umm kaddadah
# Processing Record 20 of Set 15 | prince rupert
# Processing Record 21 of Set 15 | hervey bay
# Processing Record 22 of Set 15 | taree
# Processing Record 23 of Set 15 | mahon
# Processing Record 24 of Set 15 | khash
# Processing Record 25 of Set 15 | asosa
# Processing Record 26 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 15 | kungurtug
# Processing Record 28 of Set 15 | talcahuano
# Processing Record 29 of Set 15 | san carlos de bariloche
# Processing Record 30 of Set 15 | camapua
# Processing Record 31 of Set 15 | brae
# Processing Record 32 of Set 15 | contai
# Processing Record 33 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 15 | kloulklubed
# Processing Record 35 of Set 15 | atar
# Processing Record 36 of Set 15 | lethem
# Processing Record 37 of Set 15 | avera
# Processing Record 38 of Set 15 | barcelos
# Processing Record 39 of Set 15 | saurimo
# Processing Record 40 of Set 15 | alta
# Processing Record 41 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 42 of Set 15 | cariati
# Processing Record 43 of Set 15 | roma
# Processing Record 44 of Set 15 | padilla
# Processing Record 45 of Set 15 | broken hill
# Processing Record 46 of Set 15 | athabasca
# Processing Record 47 of Set 15 | kaili
# Processing Record 48 of Set 15 | bagdarin
# Processing Record 49 of Set 15 | sibu
# Processing Record 50 of Set 15 | arawa
# Processing Record 1 of Set 16 | mezen
# Processing Record 2 of Set 16 | posse
# Processing Record 3 of Set 16 | santa catarina de tepehuanes
# Processing Record 4 of Set 16 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 16 | nacozari
# Processing Record 6 of Set 16 | whyalla
# Processing Record 7 of Set 16 | calama
# Processing Record 8 of Set 16 | rapid valley
# Processing Record 9 of Set 16 | lashio
# Processing Record 10 of Set 16 | clifton
# Processing Record 11 of Set 16 | kattivakkam
# Processing Record 12 of Set 16 | gurgan
# City not found. Skipping...
# Processing Record 13 of Set 16 | miles city
# Processing Record 14 of Set 16 | benjamin constant
# Processing Record 15 of Set 16 | kenora
# Processing Record 16 of Set 16 | port macquarie
# Processing Record 17 of Set 16 | klyuchi
# Processing Record 18 of Set 16 | abha
# Processing Record 19 of Set 16 | marzuq
# Processing Record 20 of Set 16 | oga
# Processing Record 21 of Set 16 | sembe
# Processing Record 22 of Set 16 | guarapari
# Processing Record 23 of Set 16 | suez
# Processing Record 24 of Set 16 | coari
# Processing Record 25 of Set 16 | xingyi
# Processing Record 26 of Set 16 | mackenzie
# Processing Record 27 of Set 16 | tulum
# Processing Record 28 of Set 16 | genhe
# Processing Record 29 of Set 16 | solsvik
# City not found. Skipping...
# Processing Record 30 of Set 16 | aswan
# Processing Record 31 of Set 16 | tommot
# Processing Record 32 of Set 16 | dhidhdhoo
# Processing Record 33 of Set 16 | ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
new_column_order=["City","Country","Lat", "Lng","Max Temp", "Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas      MX  22.8909 -109.9124     89.82        55          40
# 1         Mataura      NZ -46.1927  168.8643     49.48        96          99
# 2         Iqaluit      CA  63.7506  -68.5145     34.70        74          94
# 3     New Norfolk      AU -42.7826  147.0587     46.71        82         100
# 4         Rikitea      PF -23.1203 -134.9692     73.99        66           0
#
#    Wind Speed Current Description
# 0        4.27    scattered clouds
# 1        1.86     overcast clouds
# 2        5.99          light rain
# 3        1.99     overcast clouds
# 4       13.35           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
